# %%
import string


all_chars = string.printable
vocab_size = len(all_chars)
vocab_dict = dict((c, i) for (i, c) in enumerate(all_chars))

def str2ints(s, vocab_dict):
    return [vocab_dict[c] for c in s]

def ints2str(x, vocab_array):
    return "".join([vocab_array[i] for i in x])

# %%
from torch.utils.data import Dataset


# curl https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt > tinyshakespeare.txt
class ShakespeareDataset(Dataset):
    def __init__(self, path, chunk_size=200):
        data = str2ints(open(path).read().strip(), vocab_dict)
        data = torch.LongTensor(data).split(chunk_size)
        if len(data[-1]) < chunk_size:
            data = data[:-1]
        self.data = data
        self.n_chunks = len(self.data)
        
    def __len__(self):
        return self.n_chunks
    
    def __getitem__(self, idx):
        return self.data[idx]

# %%
import torch
from torch.utils.data import DataLoader


ds = ShakespeareDataset('./tinyshakespeare.txt', chunk_size=200)
loader = DataLoader(ds, batch_size=32, shuffle=True, num_workers=4)

# %%
from torch import nn


class SequenceGenerationNet(nn.Module):
    def __init__(self, num_embeddings, embedding_dim=50, hidden_size=50, num_layers=1, dropout=0.2):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.linear = nn.Linear(hidden_size, num_embeddings)
        
    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = self.linear(x)
        return x, h

# %%
def generate_seq(net, start_phrase='The King said', length=200, temperature=0.8):
    net.eval()
    result = []
    start_tensor = torch.LongTensor(str2ints(start_phrase, vocab_dict))
    x0 = V(start_tensor.unsqueeze(0), volatile=True)
    o, h = net(x0)
    out_dist = o[:, -1].data.view(-1).exp()
    top_i = torch.multinomial(out_dist, 1)[0]
    result.append(top_i)
    for i in range(length):
        inp = torch.LongTensor([[top_i]])
        o, h = net(V(inp), h)
        out_dist = o.data.view(-1).exp()
        top_i = torch.multinomial(out_dist, 1)[0]
        result.append(top_i)
    return start_phrase + ints2str(result, all_chars)

# %%
from torch.autograd import Variable as V
from statistics import mean
from torch import optim


net = SequenceGenerationNet(vocab_size, 20, 50, num_layers=2, dropout=0.1)
opt = optim.Adam(net.parameters())
loss_f = nn.CrossEntropyLoss()
for epoch in range(50):
    net.train()
    losses = []
    for data in loader:
        x = V(data[:, :-1])
        y = V(data[:, 1:])
        y_pred, _ = net(x)
        # https://discuss.pytorch.org/t/runtimeerror-input-is-not-contiguous/930/8
        loss = loss_f(y_pred.view(-1, vocab_size), y.contiguous().view(-1))
        net.zero_grad()
        loss.backward()
        opt.step()
        losses.append(loss.data[0])
    print('=================================================================================')
    print(epoch, mean(losses))
    print(generate_seq(net))
# Out:
# =================================================================================
# 0 3.4779010445731027
# The King said vet dteyrwRals nrn ao hpaR s,PO sde oltt  dG C r iarfwataaremoOsue
# ,ruesltiT np.sa is'ee
# s
# ROknr m:tnybIohm   usyFMeAydv
#  t snfaehT tMqio
# d coainAml-w  tery.e,sneo tthyy hMlm dmoif ct More ajtyoalrc
# =================================================================================
# 1 2.964444341659546
# The King said tlyenium panheB sov Smeor oisut, ts:i mc,aegke fampI
#
#
#
# 	kM,RC|A,
# SEagttosltaI aY taur inganlyef
# 'at dmoeegt
#
# oirn wofcane.
# S
#
# HE
# "I:HL-N
# EA,SOT:O: evis hhal ahe.
#
# yFd
# AT Ina novt lspur toi eou nvaog
# =================================================================================
# 2 2.568505411148071
# The King saidirunWe
# Ls teo l bole  os wouc hilmwbeu' lince,
#
# To thiitem, and the a?t
# Aann
#
# A'P whin ewinn:-ad fldad yoyivill whees mipe anm soshh.
#  l ar coust goe?
#
# SHISTOdLHE:
# O:
#
# RIILUNYFOIOO:
# The xsere toge to I
# =================================================================================
# 3 2.3968645572662353
# The King said:
# I hon sisteun:
# Rovaitest
# ond t!
# Rond fankt tilathed
# ine freul I bn lordetisitead coeg hewnlen not mh ths I hur some mat malist sheun, wy terongere drake detham thid dardat ho mit sathy hor it w tnor
# =================================================================================
# 4 2.303538442339216
# The King said mape heafdebs hagh ove tsame wich ou weshy we thouu anth by haves mime afend cofges.
# By me the as obettent'ruxs wibe E why yit whak the musAritistor houy!
#
# ENIZGY:
# And sid my dowlay tatismeres bitegh
#
# =================================================================================
# 5 2.2296147251129153
# The King saide wonmiy fould of, corde, dis goy is heum ore
# Hoy wyte, so be tordo, and thes a, dest:er so rreityt haoghiln oum soud so jon soldemelr
# Were's fuarkpur bang tise o in cofigelent'gfere mrand would yoo?
#
# =================================================================================
# 6 2.1670367063794815
# The King saids me whom. and
# I rake, somes turir deval goutencover wide pam halr mlaklats,
# Pongess my wy'd meroust; withnrfan
#
# MLARONIO:
# Ky eikh to botre ehe shaw maen to theralg inounenge and lengator heim and cifa
# =================================================================================
# 7 2.1113611888885497
# The King said,
# Bile puas his mumd.
#
# ASRIDE:
# gow.
# Shey mariss sor hereloul wich tlelruden sirge, ank hath thy; 'fo hith fraw iuf Pomamming and by neets he waard, oan thest not Hargecow-mly mest preanther Rowracoles
# =================================================================================
# 8 2.0637223516191754
# The King said congiy forss.
#
# KANTO: dall tut wa goand nawfast joger, at a ares peear I dunven al
# entestain you bustay lhom,
# Amforming but wees us u odwise thyow.
#
# TORNFELNY K:
# I dlep, an a his I thir, at spoulds
# In
# =================================================================================
# 9 2.022070801598685
# The King saidas,
# Ifer am stuctt: onc Hy gringiroge that wish forcod of to for and have that my with hoone
# Her lescrought's a vame, and we wat oup I was dmistiges:
# Hose wear'd strey for'w: Gok
# If conguence, Hind, an
# =================================================================================
# 10 1.986089059965951
# The King said fave ttarn tuul,
# No wiforts a Sosore, of dethen hame thy deallure muud.
#
# Sargates Adan'd:
# Herton, and deged the onet, To the froung;
# Panter divoof,
# I stiak.
# Thattertasl's and there with no nit!
# Wher:
#
# =================================================================================
# 11 1.9505217218399047
# The King said of cordy mouls-'bess,
# What was sporse that fap allows bad fasten uxaper; Wonder ond tham indient'ss.
#
# ROUMIO:
# May a firnt be, pleshst are,
# Whey diear my is his uwthy Methes!
#
# ROLIO:
# A pistinast plange
# =================================================================================
# 12 1.9201217835290092
# The King said that unetay
# Of tergut, I thit will is to her one?
#
# ANTOCHION:
# Woor siver steptlesly slends
# The poor, and fror and hard
# What we that consunsets that'ny my us perelatiighs.
# Here wird womplana0
#
# Seplitn'
# =================================================================================
# 13 1.894014743396214
# The King said:
# A neint to lescenther, thou sajosulged;
# Wherely Latand walh'd ighan a make that heiffe
# 'it
# Ceyer him consord, sornce syars;
# Bis upend. I bus mesty ut his oust?
# 'Dish the striost at respod; friin we b
# =================================================================================
# 14 1.8723955930982317
# The King said'd taltiun: king redes of
#
# AUYON:
# And, that frauson the, pooty, you awelce.
#
# BUCHIO:
# In barder, Gomm.
#
# MARIMUS:
# What?
# That'nd tof clainsures shall insen.
#
# ADINALA:
# I'mast with so connme'se, lond Bike,
# =================================================================================
# 15 1.8535596009663173
# The King said
# Wourldod's sinon ronence stay Galish
# A nattrear;--I now the have of of stase thronf
# ospent, jut fay thising of you dores: will hance.
#
# KING HENRY IA:
# I misied bea east cole nectherton--owhind
# pardan i
# =================================================================================
# 16 1.836680977003915
# The King said,
# Sames, thou habe and Lame lant ats whond,
# Unse, now to thly prourt whiose!
#
# Monks, is Lost fros this wifort ontue 'turn.
#
# PROF ERDCIBABHERA:
# Nontay, and radHen mide denpers,
# A' afoll frowor I love we
# =================================================================================
# 17 1.8216382483073643
# The King saidt; im-lear
# Tay ichused brettle, distulinly,
# And ninimi'wing and dearnent?
# The fal sprive'd, is to thy neade and wiw peirk.
# Thy compate's eers, and to prowe ope in
# Or me airs hims brouseds is them
# froin
# =================================================================================
# 18 1.808734907422747
# The King saids; Bowell ad yet?
#
# ANGELO:
#
# ICENG
# Angle, County my daes and near:
# Boom's nowen bance to him as mich infort?
# Oh this where seears en, the sarle, not goo?
#
# GRULEO:
# Should ea tutinoas my my to ant oubn't
# =================================================================================
# 19 1.7965284143175397
# The King said'd her of the pevein that made.
# Ares so gi-bell hagh it,--'
# If presenverchine starss, happe not gruad as me,
# A she in thee, so where thy king he styraness,
# To kisisk, but arwor's in so it geash; leath-
# =================================================================================
# 20 1.7850175217219761
# The King said.
#
# SISAMCTHE:
# I wan news so; where that,
# And weet of Caae, the shall I lest your wpuity,
# Not reaght if greece tho dowfuted soxe
# Here his shaller that but me. Sid me, and,
# Forren, 'cemether'd cobaich? b
# =================================================================================
# 21 1.774845861707415
# The King saidiens, father
# And beffech by ponust nie thy beconce
# Blught heing epae:
# As Pance.
#
# CORIOLESS:
# Away a puljeed thee the whrige.
#
# FRENIA:
# Can this in the joldar.
#
# Tihind:
# Nave Lord they indogh, he he roeer
# =================================================================================
# 22 1.7650283002853393
# The King said!
#
# KANIG:
# Wey Eqaurinison, beforion aly vitif';
# The nostry bed tome?
#
# Pristy:
# My bace this knotly: his hand,
# Is maith, nom the fa my forged him shall yeur
# And pasgelither; sleep up the gentlewanged;
# An
# =================================================================================
# 23 1.7576526512418476
# The King saids, I ponisute? What with
# as is wordesing lord!
#
# GREUCEFO:
# What wret as been cracres, the counters,
# Pill, Pome.-
# That we fan sore; bray of she care this.
#
# MENENIUS:
# This as his litpen primel see; he--
# P
# =================================================================================
# 24 1.7486898606164114
# The King said,
# It used in't for honce yo lonk.
#
# KING e Hidery:
# Botile, shall than make it aftressping to my
# Thy glook voster enish nom. my and
# Boweth to thith as farseninc not
# my drash: apterch of there fire
# What s
# =================================================================================
# 25 1.741570987701416
# The King said is to is
# Tell me, I know that but vitlool in warge:
# Tell 'tis the not I and leave:
# So is roif; the loyer pants, and by highes fool sern
# To fitorrucp strive mine mome when it the voing before did's the
# =================================================================================
# 26 1.7347959007535663
# The King saidion.
#
# KING HENRY VI:
# My of ever ars me he deavent thin; sir atcu.
#
# LARTIUS:
# Well fromfer a strrwigh! fare by cap nother.
#
# Purss in,
# To dentayss behopts the bearth:
# A rappition, ago is soghy canbign,
# In
# =================================================================================
# 27 1.7275233500344414
# The King said I have preat, broun,
# A emputuone ould bitu-in enbless dome.
#
# Serpore:
# Stispons, thee you raptled, oul this sir,
# And almemes bet an bait:
# I'll perpions hear'd's hime-ardings?
# You do not: the Ceurte-thr
# =================================================================================
# 28 1.7219298233304705
# The King said
# Ricgeder,
# Tell think mine our might him me, but.
# For you me Cleif, as four his griegn talk
# Your live the high dakeswher's my huest for
# If a knows, thou in yourself you all;
# And should their wergery tu
# =================================================================================
# 29 1.7153504848480225
# The King said come now; with rop:
# And sland you bomen: I am thele in'll.
# This may falining nothen your, your life,-ander
# To bub'ces the mreak and the may worn all euds -'wart I, her
# Stenjies he thy leard ann ence t
# =================================================================================
# 30 1.7096060514450073
# The King said's
# and preecice no I love you,
# Thou say that I am houst by orture, arus.
#
# ARIANC:
# Scayner, which you take toub, now he distuly;
# And well.
#
# WARWICK:
# My heards for ham father?
#
# CLARENCE:
# Teese; but dound
# =================================================================================
# 31 1.704271732057844
# The King said your will no uple of dore.
# The oven the wich his makhen should fave shound
# Un thint of the cait'd to him, and preceitimn.
#
# GLOUCESTER:
# Perpecher. We friend restrung;
# R othou niver though to for?
# Wase
# =================================================================================
# 32 1.6994719171524049
# The King said 'confens wowers and
# Speen to goter enents! brings he trust peets aldected as thee!
#
# DUKE VINCENTIO:
# Dore, we a seever of day for with the
# Have in his with medabs from morting and
# Muse jelred. Where do
# =================================================================================
# 33 1.6939528274536133
# The King said:
# I more' trese in the court. Cappone, he
# The gristEry Romone hout betined--
# 3I HENRY VI:
#
# COMINIUS:
#
# GLOUCESTER:
# Heasne; pristagtiens to being confe;
# In I this trurinighiw dam'd too, crein.
#
# GLOUCESTE
# =================================================================================
# 34 1.6907046774455479
# The King said how I brake my corfor
# Tued as your blood from old he standing forth have dost I breath;
# Now Good thou joss, and scelry to Bloiford with so dealhe,
# Virle our the sweise wook-to make a hass,
# Thou mork l
# =================================================================================
# 35 1.6854759686333793
# The King said well hiash denise
# At they your scresu loy perst with we art he
# craughter preneadion bring,
# The sat whit refore eupeds his wiy at O near un of Bigeing you die.
# Hay in him words him ghoul blood your roy
# =================================================================================
# 36 1.6804980952399118
# The King said my: or happeys, make in these you bely.
#
# CORIOLAN ELENCE:
#
# Livr frettrean:
# And have greute on whesuales their clost the other fae.
#
# FLORIEL::
# On the snore thy langedal sidst of the gate,
# Inetize the l
# =================================================================================
# 37 1.6775056314468384
# The King saidmence, would in can,
# Now o sun to Boegely as thele dome;
# And drowness fifts Cition, of brant are spirster
# from Dorsomnss in in did natt, and their heart
# diges sued which anst rowny?
#
# Lecose:
# His will f
# =================================================================================
# 38 1.673759835106986
# The King saidy;
# What our llove with thou be one this tomer
# qoy couldates the cator!-word, son,
# My beay of him a heart your goods.
#
# KING HENRY VI:
# Of these is fabtand of densugh o should;
# And fuirer home our coljimn
# =================================================================================
# 39 1.670674694606236
# The King said
# I did bird to strusble. What is that a shale.
#
# LUCIO:
# In who thy pibbly good tull-with not sound-in
# how tosch her kath his kind his frenging agndie;
# For the best to rid, Watter las; sir, and fall of m
# =================================================================================
# 40 1.6671647800718035
# The King said fa should whan shall the
# none, is ourlested therefore speak can out noatled;
# By learn mother! Athen ofthen, for Bheelonest.
#
# ELCOLIUS:
# Why comare as these like rounce furmen
# meadious Edword's speak.
#
#
# =================================================================================
# 41 1.6632647582462856
# The King said Yet tender withal my,
# In the seat, to go with her parlase for me
# Takedes tiltue to a hatoth'd he, and we 'tired
# And is but your radeo yearpost is a jontacked,
# If say moner! ichoul to be abols,
# And mor
# =================================================================================
# 42 1.660464689391
# The King saidour:
# Come, provort? you pargate you, thun a heart
# with an then have bronel'd from to and chark
# Than God not stone, I'll day,
# My bord not latuies this denerer'd of! and, to bides,
# As have there'bounk th
# =================================================================================
# 43 1.6568825578689574
# The King said.
#
# ROMEO:
# Sid band; thoy life tengry.
#
# CATESBY:
# Hought strike fack much mo done.
#
# DORCIO:
# What is am suar thy brick dost I have to,
# Fit hor in himber to flot. God blood you.
#
# Wildst:
# If throured Can qu
# =================================================================================
# 44 1.6545097139903477
# The King saiden glest abellor you.
#
# CLARENCE:
# How, eised so ploult they vood fid will carge
# With so. No, I do haadn; go my by to from rie.
#
# PROSPERBORD:
# Rome's noch with you are her, to cipnect love ateat.
#
# PAUDINI
# =================================================================================
# 45 1.6516708210536413
# The King said;
# Of a love, Got, with our beliff.
#
# BINEUK:
# Ay, 'len, and thou moke it thou frappenars?
#
# ISABELLA:
# Gued the up wouince thak oper aman.
#
# KING RICHARD III:
# Yought diech of Norts, wind!
# Then my death his
# =================================================================================
# 46 1.648775396347046
# The King said not as weer enter thou sene.
# The shoustion.
#
# ROMEO:
# On to dread his wrengering take the friabun this sling?
# Eswer, whou worthow he soperit to Marhiomide;
#
# First Grinend:
# As see't, it thy hapes the spe
# =================================================================================
# 47 1.646104063306536
# The King saidy none as the contine, in the
# pray, I youres with eye's Pasinmine?
# Were cran!--where me if you live tuinim? Talle a dame;
# That bester'st a constrail anjengs, and soul sout,
# At consonce, by Keath common
# =================================================================================
# 48 1.6437185444150653
# The King said to courre, whor boy's yones when they
# Thuns, not destred your queen.
#
# KING EDWARD IV:
# Whose Edwaaddend upoke our way; now hear.
#
# Thirs Clirgned:
# Wrow'ring wishall song it of he perforte you
# We t fitle
# =================================================================================
# 49 1.6407310342788697
# The King said call tender at this mept, attilowal!
# He love this to shall him suital band
# May was and a chite thee rant imine them.
#
# MENENIUS:
# I come the partery, and liye to:
# He and this masteny will seand,
# Swear s
