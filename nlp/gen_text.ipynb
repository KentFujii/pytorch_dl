# %%
import string


# ascii文字で辞書を作る
# string.printable => '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'
all_chars = string.printable
vocab_size = len(all_chars)
vocab_dict = dict((c, i) for (i, c) in enumerate(all_chars))

# 文字列を数値のリストに変換する関数
def str2ints(s, vocab_dict):
    return [vocab_dict[c] for c in s]

# 数値のリストを文字列に変換する関数
def ints2str(x, vocab_array):
    return "".join([vocab_array[i] for i in x])

# %%
from torch.utils.data import Dataset


# curl https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt > tinyshakespeare.txt
class ShakespeareDataset(Dataset):
    def __init__(self, path, chunk_size=200):
        # ファイルを読み込み、数値のリストに変換する
        data = str2ints(open(path).read().strip(), vocab_dict)
        # LongTensorに変換し、splitする
        data = torch.LongTensor(data).split(chunk_size)
        # 最後のchunkの長さをチェックして足りない場所には捨てる
        if len(data[-1]) < chunk_size:
            data = data[:-1]
        self.data = data
        self.n_chunks = len(self.data)
        
    def __len__(self):
        return self.n_chunks
    
    def __getitem__(self, idx):
        return self.data[idx]

# %%
import torch
from torch.utils.data import DataLoader


ds = ShakespeareDataset('./tinyshakespeare.txt', chunk_size=200)
loader = DataLoader(ds, batch_size=32, shuffle=True, num_workers=4)

# %%
from torch import nn


class SequenceGenerationNet(nn.Module):
    def __init__(self, num_embeddings, embedding_dim=50, hidden_size=50, num_layers=1, dropout=0.2):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True, dropout=dropout)
        # Linearのoutputサイズは最初のEmbeddingのinputサイズと同じnum_embeddings
        self.linear = nn.Linear(hidden_size, num_embeddings)
        
    def forward(self, x, h0=None):
        x = self.emb(x)
        x, h = self.lstm(x, h0)
        x = self.linear(x)
        return x, h

# %%
def generate_seq(net, start_phrase='The King said', length=200, temperature=0.8):
    # モデルを評価モードにする
    net.eval()
    # 出力の数値を収納するリスト
    result = []
    # 開始文字列をTensorに変換
    start_tensor = torch.LongTensor(str2ints(start_phrase, vocab_dict))
    # 先頭にbatch次元を付けてVariableにする
    x0 = V(start_tensor.unsqueeze(0), volatile=True)
    # RNNに通して出力と新しい内部状態を得る
    o, h = net(x0)
    # 出力を(正規化されてない)確率に変換
    out_dist = o[:, -1].data.view(-1).exp()
    # 確率から実際の文字のインデクスをサンプリング
    top_i = torch.multinomial(out_dist, 1)[0]
    # 結果を保存
    result.append(top_i)
    # 生成された結果を次々にRNNに入力していく
    for i in range(length):
        inp = torch.LongTensor([[top_i]])
        o, h = net(V(inp), h)
        out_dist = o.data.view(-1).exp()
        top_i = torch.multinomial(out_dist, 1)[0]
        result.append(top_i)
    # 開始文字列と生成された文字列をまとめて返す
    return start_phrase + ints2str(result, all_chars)

# %%
from torch.autograd import Variable as V
from statistics import mean
from torch import optim


net = SequenceGenerationNet(vocab_size, 20, 50, num_layers=2, dropout=0.1)
opt = optim.Adam(net.parameters())
# 多クラス分類なので損失関数はソフトマックスクロスエントロピー
loss_f = nn.CrossEntropyLoss()
for epoch in range(50):
    net.train()
    losses = []
    for data in loader:
        # xは初めから最後の手前の文字列まで
        x = V(data[:, :-1])
        # yは2文字目から最後の文字まで
        y = V(data[:, 1:])
        y_pred, _ = net(x)
        # batchとstepの軸を統合してからCrossEntropyLossに渡す
        # https://discuss.pytorch.org/t/runtimeerror-input-is-not-contiguous/930/8
        loss = loss_f(y_pred.view(-1, vocab_size), y.contiguous().view(-1))
        net.zero_grad()
        loss.backward()
        opt.step()
        losses.append(loss.data[0])
    # 現在の損失関数と生成される文章の例を表示
    print('===================================================================================')
    print(epoch, mean(losses))
    print(generate_seq(net))
# Out:
# ===================================================================================
# 0 3.4555294377463204
# The King said tesidmD mh aror a asheepkfdahbWahsti  eguoos rirhn oil
# bH cown ao
# e,hi :eowsimohno a,i ehrmon  tisis.a talea swhhh ,oalu hhtOsYb ealr uee eactefas iedahea htk tag
# Tsoe.IlIsmIlahsslnd
# sGe.g
#
# AEGcrTg
# mt
# ===================================================================================
# 1 2.9101853397914343
# The King said khs tulos
#
# Wefenmv rrasrurh ;orl sou dtd tell bae lnseeE taesr r othn'eefloaou tfaoks hlcd'hehy ou saeeriay aes;l nhlg s,sd  Bgat,:
# Hhege
# Edug svhhs aer winu yn ite,
# S ehidr atrian; anrtsy ?ik hse, si
# ===================================================================================
# 2 2.6435624408721923
# The King saide wecny nooc lhgut modw;
# The srevegaaddd thire byd eese had upir tc anet karertsltliul thsn fmclyglf wfhitsiy ir foshad sss on?
#
# DEEEUGANO:
# woid tram'ey muith tar ofe or'd evgfin tethR
# or he yihe tr so
# ===================================================================================
# 3 2.446467430932181
# The King said luen:
# Fr yraupbegr
# Nh he'e thlal'e
# Whoud
# Hy be whaulwrddgrong coutem ser'le nuoums.
#
# OEUIY-NS:
# Vferepy thit sereun soun syout ordes bheund aunge thou to arsmerad, moy by sout yer ape thwle, I
# Whentinl
# ===================================================================================
# 4 2.332917310169765
# The King said thepef ltore, hoe I dert anterticterte, that brervelle chorg an, vee pound.
#
# SARLFNMUA:
# And uutll, Rale ce yra,
# Lenge: thes thas I sous of'p ane thy ang, it wfourwenus ankelt'nve ywed;
#
# Do:
# Rebesoevle
# ===================================================================================
# 5 2.25597670010158
# The King said'd ncith dod moticounw hter dokin, 'ecary torulf on my crove priires. Whor ach.
#
# F+itne:
# Ho at thatettailte to, mor,;
# Lone ay tht gharkso gisire buvergilsenas, I band in sescrecle thof: it.
#
# LEALD:
#
# Sa
# ===================================================================================
# 6 2.1925318690708706
# The King said fouxts eow
# by meim faul! she weing noul hener?
# Natees to yu kich thee kewwnshow witrerul. Cine, yive tndume ir gewheth youu be gyale and in the soustel be woum were
# the theand=er, gishow yith sveuorge
# ===================================================================================
# 7 2.1371301542009626
# The King said;
# Mepyer I'bpone, tis un not allens our
# Than tor'dn hour: me
# Hizerces hes, womerk's, theil.
#
# GoDHII G AUTF RINTR O RIONCHOLELHIY IMHIAR:
# Theg anger Mucrere,
# The srore!
# 'now thou worth thear.
#
# IWICAT:
# A
# ===================================================================================
# 8 2.0909463351113455
# The King saidlanced il yhinone I py motigin the cimcay.
#
# HERRMORE SENELENTE:
# Whou min, I woy the oud mid;
# But I spenboun fet.
#
# Reet:
# Thae hovew dill thou be merust cerhpor beths, and worgh tere in gekercn cum for c
# ===================================================================================
# 9 2.0519780363355364
# The King saidar't weriebching te aly your.
#
# KKBOCPISO:
# Myt there wicoogm than thit hy pored, cmimeg you sone nomes id treine thee,
# Bu, heals veyy angon
# Tsos collo ugmioufil the maliboedegret mipe.
#
# At ICG EKLi: Ay
# ===================================================================================
# 10 2.0179656737191336
# The King said thy pruch hanlllast tuonisles mriagoo dut in to gish and there as to metew
# shast thestair jyting
# Nom In thut, antholl,
# I pretayt ack'ss is Antek bellige pare to my eettle,
# Abment;
# Oot'd qowrast whoud
# ===================================================================================
# 11 1.9889661359786988
# The King said ack mull,
# The me best Qingurene prows thatrough?
#
# GoRRTERNDIA:
# At hange,
# Apdep; triemern filldo.
# In
# The leect ingaed e'ch this a choth anss nime rejests-gome reebing hentuks surian
# Then meres' base in
# ===================================================================================
# 12 1.9636909661974227
# The King said:ives angmrent!
# Wha parobly om and meret now quelt.
# For caores be Lutiry and gonourt yorgey: rercide
# forlfiles, you longs lics sworctefice thee:
# Them made
# Herge the, chate;
# Fom.
# 'Lurriens mourtoriny th
# ===================================================================================
# 13 1.9414283227920532
# The King said lest!
# laps.
#
# SORIOLOLLORA:
# O mey, me I beto bune, Iwrest lerke ang wioy make; the poe-leign my me my wanily,
# Hast therewelled.
#
# RKISHA KIF RING
# A: Pyurre, of thy o orpeed and for tell!
# Lerninow.
#
# SLiE
# ===================================================================================
# 14 1.9217086941855295
# The King saidewer usseest terred so,-wear cheer yoush,
# I would do naisens to mastein, hound then me leish wett mugreing my tor of bedon to hen mart you now bees a deve,ele! What after as and me, of thou egence?
#
# ON
# ===================================================================================
# 15 1.9043494599206108
# The King saider.
#
# LORGES:
# Nou, me like fistows arcutio, tilr;
# He sorn,
# But moneilg,
# Why her, rome, a loce my woro'acher do tood Taades know,- revess undoo itset?
#
# KICF IBAS:
# Groufh cristy
# your at murder, fan trush
# ===================================================================================
# 16 1.8887973730904715
# The King saidy;
# And hind you hath on,
# What onarble thas the mast
# di? thus, on welr
# Nim and you serredfon your hander to some.
#
# MESANTES:
# My bay, bited depeatle fordecte knoufloul
# in it, let take
# Your your is of pre
# ===================================================================================
# 17 1.874564996446882
# The King saids, and these pawith
# Selumom hive, for worded as vite goidishy in fichseed'ling me frown, more old gought momes carding to ksowings warle with e walleds'd chouk with sars?
#
# SICINIUS:
# As you rean good th
# ===================================================================================
# 18 1.8621849707194738
# The King said so wave to her stander Your with be by me noly sis shand.
# Ravan mathurfore a prown'd then menesn. For homing searn and for mip
# That it not my ry heink, halg, a with laeves thearre! my carve and helf a
# ===================================================================================
# 19 1.849209258215768
# The King said.
#
# ETER:
# I bap, moufthe rother king thefp in my mant wilr vucter! this ladu gou, venr lathos, reven!
# Hid party! whyo of swict me any trewains: and I promether's by I:
# Confer, eye is kputhing,
# And at ch
# ===================================================================================
# 20 1.8380574546541486
# The King said things icluble.
# Hall be last, apoting gought. and aper'd,
# Here sufperprased me Sweally.
#
# BENORE:
# At enmimest lock my plaed of to he lerge.
#
# CORKADIIIBLO:
# Sir miresther, my frious fe exth her
# Retredy,
# ===================================================================================
# 21 1.826892647743225
# The King said to nave
# The shepame thoust of port dirtor with, and cakele your doth with savemence?-- have estef,
# And marnod
# And is there hement montry,
# So into apther.
#
# ANETwI
# Uno, cead! perbeas to with Gog.
#
# GRAKE
# ===================================================================================
# 22 1.81790821824755
# The King saids the spercuur?
#
# POLINGENER:
#
# He RIVI:
# I where
# ship duncs! O, and Ol, 'ark, beliplpo fare the archery,
# And he have by hows trainion
# With my athon
# Do me saFor law:
# Anleet time for I quiceline her abdy t
# ===================================================================================
# 23 1.8064653887067523
# The King said
# Well, sturtpinest wrake that culing that mothimeringy; all Emjor ancive dedrathers
# And it wel corch.
#
# KING CERDITI:
# And quistioo:
# Who canded not; as come of his,
# That spatering, and cromeray tosbcnsut
# ===================================================================================
# 24 1.7969726276397706
# The King said;
# And ret of canine. Thy seld have beardtedt, my repling of and an ablites
# Fadise qemarl, shis nowerlens:
# But nubtuse.
# O priter, but with cosh rike stremeblained and abton of her the
# bread connarlor by
# ===================================================================================
# 25 1.7869605350494384
# The King said, Buges,
# A woxen soual loor durt-ewis on are granful house, the pray do
# We to Viaves up bay brother'd by ouning'd. For himther averow light sict will your will the sive a gumongle my
# Bold; ip sumpore.
#
# ===================================================================================
# 26 1.778278923034668
# The King said;
# Of lord I sone to yur offord of the thoungsh for lobth,
# apurless as turk be in--A cownsne.
# Not lay the wear proon;
# And hate Triantet Herpect,
# Whis if it my hade in alle
# More we in thesellanps,
# How if
# ===================================================================================
# 27 1.7694321530205863
# The King said the doze.
#
# MENENIUS:
# Whir not worrbling your stasks have old the weet imfans.
# If pelowregher drence,
# Not cristand.
# Thas lest wad memper-wary,
# To plew; the gequecuin of our atsed fall somen, daive,
# You
# ===================================================================================
# 28 1.7604317161015102
# The King said:
# So the dopecm fay I sir Vispice my more, and remerming brounds mainiech
# A tend the sir and bnot, nune on my would rome,
# I thain him mean:
# To seefort, and fiish fear your and proles are sha oueth
# Bay
# ===================================================================================
# 29 1.7533392422539846
# The King said it mesce your hate
# And you bead to she hone, mondeds,
# And have that it yes me him hose all'd;
# Se haods?
# How streen spy, thy sougan, Lastle I brother nainiry,
# I not this mouses! to will teart
# On not ma
# ===================================================================================
# 30 1.7466885737010411
# The King said: lested vile not mes londed jom youth.
#
# NOXNI:
# And hare with to wade pretios,
# Say, tut my lid engelloungrous and live with allle
# .
# The his stoung'd here vrome.
#
# MERCUTIO:
# My he pretace fay.
#
# Cusize:
# W
# ===================================================================================
# 31 1.7400287716729301
# The King said, truth thought-fof, him homeo, intearred,
# And canselferful nexen be to thary of the comes,
# Thus God, weme with come tast loves,
# Say, he have her you+ds dome. Cost there good there must if
# and my house
# ===================================================================================
# 32 1.732898975781032
# The King said his lave I so Grecot it and
# Must if Gray or, for if oung, entents;
# I hink: would I chy weart stake her.
#
# LUCIO:
# What thy rogy farth me to had wikh.
#
# POLIXENES:
# What uwrut alromas is me to shoo!
#
# PETRF
# ===================================================================================
# 33 1.727710507256644
# The King said, you he come is a more for not reperder
# A fite us, gost he canst will ake confertudlient?
#
# BRUCKETRUMIO:
# He pabuts and sweplwial, I day I
# scaves this having how I like.
# How is will by from sae is king
# ===================================================================================
# 34 1.7227973794937135
# The King said her asdentenous
# But than earth and I be yet woogh
# Lick it my mastans: Richush'ds I, it my bost
# Shouldst of with tisad;
# You by thee tify lihghing feigntend?
#
# DUKE VINCENTIO:
# Therewarthar oit in for thi
# ===================================================================================
# 35 1.7176402357646396
# The King said,
# And your fercent the boke. Ferace of Tromests
# at a mance her upart'st you mointed.
# Contanciolged Rike that casks mer him; I what her the do-pristesses prave
# To it of what apting'st her 'under whach u
# ===================================================================================
# 36 1.7126290621076312
# The King said off may lovast ay minogaar's nothy.
#
# HENRY BOLINGBROKE:
# Thint, will dood hove but the our snear of aning,
# Toile enruith'd.
#
# GLOUCESTER:
# I plast for 'tis forfud,
# And an amsell to from is foom; up, to b
# ===================================================================================
# 37 1.707545759337289
# The King saidost thee at Lirdat-come:
# And upstor, but our hand'd, Pythen my praight affate
# Crask pray, this prome and of is of tell then be thou been;
# And of if excwart'd will be deveren,
# That the and that gratobly
# ===================================================================================
# 38 1.7042089223861694
# The King said perts of beth that
# Thou love of if my land: I have of then a not poce it
# Thy men parrous in to me, you throws of me!
#
# KING ICHARD IV:
# That all,
# And of as have is not that sing one it,
# And not you Made
# ===================================================================================
# 39 1.6988384566988264
# The King said with my lord. Loice, 'hife ralled.
#
# RICHORWIUS:
# Wellow, them, gence are at contoss arged of fived
# In breathad faresescel'd
# Gath I if bort all like, for stend our rance:
# eese go not scorrege: thy came
# ===================================================================================
# 40 1.6944869198117938
# The King said brove know your rein.
#
# OXREMIO:
# Now.
# What
# The gaves groats at
# cistiger'd a peen of the cloity!
#
# FERY OF
# I, do with Sownders excourter thas gread
# All eave lyinmens
# The play the helve thou axtly worr wa
# ===================================================================================
# 41 1.6907746117455618
# The King saids; nord. Mark. The gonent; pertion bear sughth.
# The will be just we noy.
#
# HORTENSIO:
# O merechand what no words,
#
# MENENIUS:
# So have the fear die, he kinst tame inlencue:
# Hall hast cre may Wade at the be
# ===================================================================================
# 42 1.6867115661076137
# The King said.
#
# LADY ANNE:
# I he quear give to stook; could;
# Your my secue, to him hasty cried the haper'd retione!
# This do it would doOg headth is asplocious unjet
# you father reture, and her your hour heart to the
# ===================================================================================
# 43 1.6827730812345232
# The King saids, I was very myself? wall.
#
# ARHAR HARN II:
# This mens you mone.
#
#
# GLOUCESTER:
# Groke stand hatales wemching, beth your falas him now on
# Canrutiel, what domehent do,
# My let your lingsny templity fathous,
# ===================================================================================
# 44 1.680327558517456
# The King said shust mymbutter, all ever,
# Or rusious word thone she, well to day's sing:
# You yene disqure been me destleoted uckion day:
# By as thee, imperit-bey: you!
#
# CORIOLANGS:
# Take and do's entreatarace.
#
# LEONTE
# ===================================================================================
# 45 1.6770319979531425
# The King said last, yet thy wigh known.
# And myreas' this laungng'f searty heath.
#
# MENENIUS:
# Your arwicy,
# The see and suepad now, thy incive no stoo
# 'this of that be mate,
# And stateing old God spoar
# If here abring t
# ===================================================================================
# 46 1.6737307957240513
# The King said inceedifest.
#
# LUCIO:
# Some seean it sunmecty Erw boy
# We goils the righty on Clipherdoker no courst,
# Were Jeors, you is the raced my father,
# Now thy from with to my matter, do-ope, which heise!
#
# QUEEN M
# ===================================================================================
# 47 1.6706502001626151
# The King said his shall the reseld and place'd
# To morther, say ducter Stoplow finreth,
# Dighon'd: in I protles nosewing! of his prayers.
#
# HERPEWIS:
# Betch on hivard you seeds, here.
# Is my his deboy'dn-gunnleed; their
# ===================================================================================
# 48 1.6679255403791156
# The King said with you lovivessy I sich ronges?
#
# TRANO:
# Sey: to sfath't of the swesh-cown in shaswer indeed,
# And Hichtlary, my Yes's old your monkent's chaster.
#
# PLORY OF YORK:
#
# PETRUCHIO:
# O, nought wars you to not
# ===================================================================================
# 49 1.664580295426505
# The King said and me lisolians not all
# the word thy if the wars, my forgiance.
# Is a shame, proke as least woll your encesune
# To is heist is rught so where Testoble lond
# To eove the gran. If be morth, good dage have
