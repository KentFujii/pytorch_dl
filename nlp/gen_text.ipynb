# %%
import string


# ascii文字で辞書を作る
# string.printable => '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'
all_chars = string.printable
vocab_size = len(all_chars)
vocab_dict = dict((c, i) for (i, c) in enumerate(all_chars))

# 文字列を一文字ずつに分解し数値のリストに変換する関数
def str2ints(s, vocab_dict):
    return [vocab_dict[c] for c in s]

# 数値のリストを文字列に変換する関数
def ints2str(x, vocab_array):
    return "".join([vocab_array[i] for i in x])

# %%
from torch.utils.data import Dataset


# 
# curl https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt > tinyshakespeare.txt
class ShakespeareDataset(Dataset):
    def __init__(self, path, chunk_size=200):
        # ファイルを読み込み、数値のリストに変換する
        data = str2ints(open(path).read().strip(), vocab_dict)
        # LongTensorに変換し、chunk_sizeの分だけ塊にしてsplitする
        data = torch.LongTensor(data).split(chunk_size)
        # 最後のchunkの長さをチェックして余った部分は捨てる
        if len(data[-1]) < chunk_size:
            data = data[:-1]
        self.data = data
        self.n_chunks = len(self.data)
        
    def __len__(self):
        return self.n_chunks
    
    def __getitem__(self, idx):
        return self.data[idx]

# %%
import torch
from torch.utils.data import DataLoader


ds = ShakespeareDataset('./tinyshakespeare.txt', chunk_size=200)
# DataLoaderによって(batch_size, step_size)になる
loader = DataLoader(ds, batch_size=32, shuffle=True, num_workers=4)

# %%
from torch import nn


class SequenceGenerationNet(nn.Module):
    def __init__(self, num_embeddings, embedding_dim=50, hidden_size=50, num_layers=1, dropout=0.2):
        super().__init__()
        self.emb = nn.Embedding(num_embeddings, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_size, num_layers, batch_first=True, dropout=dropout)
        # Linearのoutputサイズは最初のEmbeddingのinputサイズと同じnum_embeddings
        # num_embeddings分だけ確率を出力してall_charsから尤もらしい文字を選ぶため
        # linearの出力は(n, n)
        self.linear = nn.Linear(hidden_size, num_embeddings)
        
    def forward(self, x, h0=None):
        # xは(batch_size, step_size)から(batch_size, step_size, embedding_dim)に変換される
        x = self.emb(x)
        # lstmによって、xは入力(batch_size, step_size, embedding_dim)から出力(batch_size, step_size, hidden_size)に変換される
        x, h = self.lstm(x, h0)
        # 線形層により(batch_size, step_size, hidden_size)から(batch_size, step_size, num_embeddings)に変換される
        x = self.linear(x)
        return x, h

# %%
def generate_seq(net, start_phrase='The King said', length=200, temperature=0.8):
    # モデルを評価モードにする
    net.eval()
    # 出力の数値を収納するリスト
    result = []
    # 開始文字列をTensorに変換
    start_tensor = torch.LongTensor(str2ints(start_phrase, vocab_dict))
    # 先頭にbatch次元を付けてVariableにする
    x0 = V(start_tensor.unsqueeze(0), volatile=True)
    # RNNに通して出力と新しい内部状態を得る
    o, h = net(x0)
    # バッチごとの、時系列出力の最後の部分を(正規化されてない)確率に変換
    # 正規化しても良いが、torch.multinomialは正規化しなくてもちゃんとサンプリングできるのと、ソフトマックス関数の分子の部分だけでも十分サンプリングできるのであまり意味ない
    out_dist = o[:, -1].data.view(-1).exp()
    # 確率から実際の文字のインデクスをサンプリング
    top_i = torch.multinomial(out_dist, 1)[0]
    # 結果を保存
    result.append(top_i)
    # 生成された結果を次々にRNNに入力していく
    for i in range(length):
        inp = torch.LongTensor([[top_i]])
        o, h = net(V(inp), h)
        out_dist = o.data.view(-1).exp()
        top_i = torch.multinomial(out_dist, 1)[0]
        result.append(top_i)
    # 開始文字列と生成された文字列をまとめて返す
    return start_phrase + ints2str(result, all_chars)

# %%
from torch.autograd import Variable as V
from statistics import mean
from torch import optim


net = SequenceGenerationNet(vocab_size, 20, 50, num_layers=2, dropout=0.1)
opt = optim.Adam(net.parameters())
# 多クラス分類なので損失関数はソフトマックスクロスエントロピー
loss_f = nn.CrossEntropyLoss()
for epoch in range(50):
    net.train()
    losses = []
    for data in loader:
        # xは初めから最後の手前の文字列まで
        x = V(data[:, :-1])
        # yは2文字目から最後の文字まで
        y = V(data[:, 1:])
        y_pred, _ = net(x)
        # batchとstepを結合して損失関数を計算
        # y_pred.size()                      => (32, 199, 100)
        # y.size()                           => (32, 199)
        # y_pred.view(-1, vocab_size).size() => (6368, 100)
        # y.contiguous().view(-1).size()     => (6368)
        # contiguous()はメモリにのってないtensorを計算するときに必要
        # https://discuss.pytorch.org/t/runtimeerror-input-is-not-contiguous/930/6
        loss = loss_f(y_pred.view(-1, vocab_size), y.contiguous().view(-1))
        net.zero_grad()
        loss.backward()
        opt.step()
        losses.append(loss.data[0])
    # 現在の損失関数と生成される文章の例を表示
    print('===================================================================================')
    print(epoch, mean(losses))
    print(generate_seq(net))
# Out:
# ===================================================================================
# 0 3.4951481083461218
# The King saidc oWd|rCondenw
# hls
# t,a n innddeto yafW nee
#  hM,e\dao  Iaw .gI eekc rhhslteb e
# n le Rmuto>Tmtohrtpoiteoh oW
# teaosyN
# uiivaaeN ohe,v s naui heyon ddvd
#  k# teein-stto: N nStw4v;fha Aet waReen Gt,soeihr!Bt
# ===================================================================================
# 1 3.0123700101034983
# The King saidf we aainis agk yathe isn lagmu wisy
# Atobr ce atmre tiot 'alliro fr nale iost chdrevS tihy hs thamame lacltn pis hnrsca aiodt oe nah!
# yutnanae ageenL
# Au goo messer,
# ItydC. By: ad.d
# I delll hyet,s sytr
# ===================================================================================
# 2 2.6087265287126815
# The King said!:
# ath,Wl
# -el suchnlit'n y'or theNU
# ske:tctfale
# Wule
# Uomy whes ad was, mp.e
#
# Ye de,: bory: I heurrbes: whare nes hp ou rabe,lt: ermike
#  ouss navele whlar
# Yodncattir ue,
#
# YU,N:
#  horls bto gteee oL mer
# ===================================================================================
# 3 2.4075860813685828
# The King said theres sut lafgose het I;
# Kt: ti yuner
# Hid hohe'gne urbted ere venes, the, ar wencanh thesn vythbely: sase eik gore tis the mavhy lil lit ol cofbile soulsaln amde
# Cot thit dast borle nast, h'is
# Late p
# ===================================================================================
# 4 2.3129516070229665
# The King said the; I.
# Bid whe medorittove the lom, Het'p ou:
# Ons's, adilk eou!
# The cine
# des,s bad vayt cha, rihltk, yo mned
# Whound masder woifor, nyere I Garine hos wky as sordlinlasoe!
#
# HRRIABD:
# I IFdor, yarcanith
# ===================================================================================
# 5 2.2451226561410085
# The King said surcerald; beve to nog burgours!
#
# NINIVUEO Anh shasgor Wour, fo thy sunder Biste; guld cnow Is jivest thoorer
# if be ent.
# Le trour
#
# LUNRIOCMIF:
# Cace, doregce;
# What besoll that me inte unle puedlowud, b
# ===================================================================================
# 6 2.1853042030334473
# The King said you
# In ror; Avakl we erichets il.
#
# VCeCENIY:
# Boch kyue a whouggo seld ner:'d,-bath, the as pa!
#
# sING PMORALI:
# Corill fich, wot mrats come syuaw dorsuik we, I, sand! badron!
#
# Borll,
# Thime an hea hy thi
# ===================================================================================
# 7 2.1339126764025007
# The King said,
# Mith.
#
# INCESHEEL:
# That
# dith soor.
#
# VORLNICARTIU.
# Lither pkarve all teth, your so use. dis eelpo niph as sinok ny hive,
# I art me not;
# Buvy ssien echel what frot to and hote bes, mare to rord ialine fo
# ===================================================================================
# 8 2.089162686211722
# The King said?
#
# OAALO:
# Ralls, go prantons.
#
# CARCESTETI:
# I!
# There cove pyilldens chate houngull in hoon my thefe then maake.
# Whing made male not, oor mocutpvilal, plats witl of Tuabe?
#
# MCELIOUM:
# Bart.
# BRit misert.
# N
# ===================================================================================
# 9 2.052445841516767
# The King said your my her the meeds the kmife all soucp tham theuud Buring hee wroL Toow thow lorse fendlacts bith aster us my now lamess oppeadce hast misietss a hean eeinces. I peahl.
#
# RYARK:
# Wad, to so cingey th
# ===================================================================================
# 10 2.0198250014441355
# The King said!
# He be, wrokes we thet say the, anging Groovy ser.
#
# ROLIUE:
# I yue
# I covelt not thite Is knat,
# And lincing hive
# Lith the dirss whack warl thbreines patitives. Soweld'd
# And strich helwly thove you eming
# ===================================================================================
# 11 1.992042007446289
# The King said, aft by thas niws?
#
# ROBALSA
# LENHELNA:
# Tith,
# The ir non the, the sours thet Q thy had not it
# pwest have redceatonty of the hen whak dorl
# I wishatod fians:
# Ant forlnnay ond seatle.
# Thest to hithry, 'inf
# ===================================================================================
# 12 1.9663713809422085
# The King said May to
# shere in buslise, cwuth hound; I reow cin to in sore, I slay.
#
# ARILA:
# Thittar lolnch's our To h'l that's pyor?
#
# TARTKARD,
# I:
# We thine your wreed of Lorves dey the debagge-s-ufingll, dorl, a lei
# ===================================================================================
# 13 1.9448999731881278
# The King said tis'sty? fand hother secged op would
# Whoughemans of bath
# The browicg you;
# Whas true, mistrike be nom, by slort
# Bonser, lutirs
# A drues and liggedty yould when here inay, Fegiy,
# My
# if fording not noirsm
# ===================================================================================
# 14 1.923436462538583
# The King said this longy doy shay'd mayser:
# For his fict he groy gewint be dand what cwups.
#
# AfRUPRALI:
# God what as eting.
#
# GANTES:
# Garire now we pasy;
# And I greeot shy brosl
# That of his now sandly of Crorent dost.
# ===================================================================================
# 15 1.9058365181514194
# The King said;
# Thlo, then hath a lived aughle; is is, I have youl a kyou he were worsosce me, boost and in Bacatters
# have windot to geect there consuck,
# And flesor-staund,
# And coller prove, a lakate!
# An to choutno,
# ===================================================================================
# 16 1.889326992716108
# The King saidsss me: cearce, comantuy or caly anstined!
# I' micht sajuus wourd loocer'd,
# And pit.
#
# SISESTEO:
# Thy it.
#
# LOLTES MISWINIUS:
# But I sinvent te it the vith in suce
# conterfors we graies, surine?s prand; acen
# ===================================================================================
# 17 1.875377572604588
# The King said the bepuld---
#  Dam as lerpong? mat'tel' and farema--
# Thy prishlite,
# Dy I yalk it.
# Fith thath.
#
# FirRes:
# Our then!
# But now
# To and thy levith,
# Molloul
# Me,
# And: thee to comion lietirito ergarses on catoni
# ===================================================================================
# 18 1.8613900913511003
# The King said indy it we flale is
# Fork Muct plarandif.
#
# DUKEN CENNIO:
# My liar we entirmaud's of I he proventer pillsmantish lorters a siess,
# Meid sherath hipher nol a I bshlo not I have man.
#
# FARLIO:
# Whow our speae
# ===================================================================================
# 19 1.8501205233165197
# The King saids; and yishtar oth Lord; hid depry?
#
# KINGEN RARGA:
# Why lazad on to it the shild of thereset is stistent'd latorow's is ye fixly
# bes'll too doave
# For hards,
# And Iiry onhen;
# Tresenglakion,
# Priternot, spe
# ===================================================================================
# 20 1.839255670138768
# The King said, thing,-mice that eyglave forgo's then merce
# hoald:
# Lewers fal he liine!
# Mading done it wife a such myseak bedner wouds menged fay death let good gooker: thou Wae to that faits I overess
# what sainse g
# ===================================================================================
# 21 1.8274997316087995
# The King saidy my miry, this grow houf other and erver?
# Here us will;
# Where true be!
# Ie, come:
# My.
#
# ANHENTIO:
# That leal my stord caadeik share bayd:
# When, weod take grainer? where op a forth I weldemt on's, defess;
# ===================================================================================
# 22 1.8189365243911744
# The King saided forthize death reatwrys denard all had got heart.
#
# VINIEN:
# Goz't his darpy you are I barires upon in Yorge, we cleal
# Sty, thy werting,
# And sald is that sirs, sho foven.
#
# Provee:
# Less bitliov fanived
# ===================================================================================
# 23 1.8091503606523787
# The King said are I might to desborous lood love to-dord of Efphe sir offorters'st fill cover me.
#
# CLIMENT:
# Whas.
#
# SAMANUS:
# Swey in hilt, what that gnun acrilpy.
#
# ROMEO:
# Yumier, no flatter of no in
# So:
# Tiour.
# Then
# ===================================================================================
# 24 1.800015822138105
# The King said thou kret it
# Withth pack trake not a lass.
#
# PUPTIN:
# -Proelfor should to
# Take you.
#
# LORD Horrow:
# Me, I thy exil amper,
# Nawers that, whilele lalece; a farch the wist niell'd holl, and
# bligrtice with.
#
# P
# ===================================================================================
# 25 1.7902391079493931
# The King said, in they to this olone allse,
# Where's, hear well
# For I find the, norfpes thy pewarbpd: times, abwant
# Be my seak;
# Thy stect thou kenter,
# I the wagpl buse is hearts have a Camunt aid of as saush?
#
# KING
# ===================================================================================
# 26 1.7817732913153512
# The King said soul!
# And he as, worchire it you confus, sall witle in the monout's
# The sover, hone grak-at in jost what
# What in had herrer and tears ald knove Cawis, do that and alreds browing
# Merve your with how;
# O
# ===================================================================================
# 27 1.7724420826775686
# The King said.
# Dake,
# But lasse will I hast hen we loziend, so ever infertison of the a 'null,
# With notw other: nes, flowelfeds of the heave,
# Why do pair, Lentle to in ervy,
# Low,-hartch a hupbers, no confiegtion was
# ===================================================================================
# 28 1.76426645892007
# The King said, my facenp:
# Hislle? and her from thy gettair of there
# snaunted, what.
#
# SLAMINIZESA:
# For he lan-here tiwe archer and, with you jalf his.
# Is his greatice for the chame if now!
#
# MENENIUS:
# Wilst, to med a
# ===================================================================================
# 29 1.756602852003915
# The King said onitchy
# wink, must fitow, no devole thought'd, bele well;
# The wall farse!
#
# CORIOLANUS:
# Sooth is now I prowiss of your havited us niving,
# Lid than, his seppriedce.
# To malted', you.
#
# MENENIUS:
# No, I kin
# ===================================================================================
# 30 1.7489258738926479
# The King said hent a eaving.
#
# ROMEO:
#
# GRIUCES:
# She with my kingre honed; who  ourbife.
#
# LEONY:
# Nouselow liding 'tis crugk I furdan arl their facs.
#
# NIZERRD II:
# Themes your chower so not and to sems approwise'd pard
# ===================================================================================
# 31 1.7428176484789166
# The King said.
#
# RICHARD:
# The singeing of they of not.
#
# Second: Sale;
# O the pates drait, from ther mance haghfer.
# We that hast with surpe are opcutmy:
# Put my may romer denids franes
# some hamm to hear not netend thas
# ===================================================================================
# 32 1.7376725128718784
# The King said him, and four me as the peasure;
# If, but him a boners: tother, in the want thought if Amanst:
# As will the at Clack my derousoss: afaliders midh'st good I come.
#
# TRANIO:
# Whis drigue you, hesire, revith
# ===================================================================================
# 33 1.7320106227057321
# The King said
# dijend apverer king ugus's some makes.
#
# TLARIO:
# I have therep is arse in inserved of the negricd as the wollowging a flar,
# Aid we thou emperoestyiles, and Evas youger on have stong,
# And beav Estons wh
# ===================================================================================
# 34 1.7265364129202707
# The King said.
#
# MENENIUS:
# Feathry, will tefpondsulf, great onsur cosfer of my his fam, yet.
#
# VILENAH:
# I propelt, beess helfioses to the now,
# Henceniesa shall come her I purded, and veleay in.
# Yet, Tounsled onictius
# ===================================================================================
# 35 1.7218452998570033
# The King saids well?
#
# First:
# Corcannous beswy of the choose too fead reaveds and protimed.
#
# FRIAR LAURELNA:
# Parter il of not to slence murd of your offord,
# I! that a heod had ba'd awife poon'd
# And me as me.
# The hop
# ===================================================================================
# 36 1.7167613063539777
# The King said:
# For worbt, and let lid heart.
#
# SICINIUS:
# Choce, Wallilsp approve? pecapfarvigmenhd me to curry not my lill
# Well, go at a saicce dacent we bea'ght
# And to manvertue, are no man: for my pather and deaw
# ===================================================================================
# 37 1.7128905146462576
# The King saidny! then: thouy not sides of heardy
# I flartuar firelich dome hate Rome.
# Uncond where
# Marry, no vorted caller onty,' priinge!
# And heen, old sir, to nock olfors!
# We To manies, that the inst law are her'r
# ===================================================================================
# 38 1.7083273213250296
# The King said;
# That for in Vare? Gid a time.
#
# Second:
# Three in thy, is hapfe not thin tonemy here queen,
# On thange oppence you to-scieds west the mand not
# Aferchaunuch here death that his purfio, it we'll beswacks,
# ===================================================================================
# 39 1.7042723097120012
# The King saider, that when old and I got retell
# Not be to in like time faichor our selfor
# Moruse plain my will deums thou prise you;
# Wuth to swight rows, and we day that he Senerom fiwch hiin and my viise
# What make
# ===================================================================================
# 40 1.7000182206290109
# The King said; shimch thense bles Yortt.
#
# KING RICHARD III:
# Hage for my at our heart of hesp it him.
# Is flis, be that his trouth,
# Non'd un the grants, my rame as itsell,
# So farvered in wechace, one, your say not;
# N
# ===================================================================================
# 41 1.695744548525129
# The King said are of him?
#
# Secord Sirry:
# Yem's dore heir speaks ord the find;
# Our finder the sprame groy idse and.
#
# KATHARINA:
# How dighto was a hand procoze. the paig mage, so,
#
# And he Kerimor on Warcrick not mis's
# ===================================================================================
# 42 1.6924427379880633
# The King said my hore still,
# Thou by yeard the been her friendy
# God ontees hive hath rithly slikests wife in singers;
# One well swake? the' letfan obed of Weat the begar.
#
# DUKE BOMENSI KEND VINCENTIO:
# And adred!
# For
# ===================================================================================
# 43 1.689545842579433
# The King said--thing thou euth.
# To be him peret the Romee hence. Down.
#
# ISABELLA:
# Come rousines? Gen you, whal forth To bup;
# No besciment, it my the ligh'd,
# But God to not patiness! be herimfuild tast!
#
# GRUMIO:
# Go
# ===================================================================================
# 44 1.686153576033456
# The King said of Yinky off
# better farwick God for my merty would eurth
# speet by go: upien be lord,
# And I Darry told; by his quocuch.
#
# Pongerote:
# My she enjait; should yet whean enk'd of the pereet being.
#
# ROMEO:
# I
# ===================================================================================
# 45 1.6822306653431485
# The King said.
# That I that the fill didse peen,
# I ere by with, besip, and il, placion.
#
# MARGAUS:
# Her it I nat be make,
# The sengmence; and I have drmitty?
# Wo me shall him his away-never domen him:
# If and thy report
# ===================================================================================
# 46 1.679390025138855
# The King said,-- Bungn the some
# And there it hich lovein; extial bed, in seace we prindles,
# For a king 'lat for stands thou that herow
# Modent in my trute of my show,
# As the herathed to longer tarrbos and like
# Now O
# ===================================================================================
# 47 1.6763246665682112
# The King said Ray
# See and foul wrind mal thanishath to noblave
# Wiel upon their swill bear for falluting condet.
# Nony, then, that son thou some, and his cann; you, swear
# Will her em, thy saadingry he against, come m
# ===================================================================================
# 48 1.6740950059890747
# The King said to-knere.
#
# MARCNIONEM:
# He weepfy to 'tis snow! Seance him, what ouch that your do to
# may, hell in should maces gon.
#
# KING RICHARD II:
# Where such Engligc's to hath make ourm Hindance
# And name,' him mak
# ===================================================================================
# 49 1.6706312847137452
# The King said stizen-thou
# To wade of my justing ranoun'd time
# And she cand ansues waw this bignt of among plewe as forths:
# Inadausing stare, you sorrow to know not
# Love courstam, I be antabneds Endst. Love can did
